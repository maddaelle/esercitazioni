# %%
def sommaduenum (x,y):
  ''' somma delle variabili x,y'''
  ris = x + y
  return ris

# %%
somma = sommaduenum(-150,100)
somma
# Out:
# -50

# %%
def POSNEG(x):
  if x < 0:
    return 'il num è neg'
  elif x == 0:
    return 'il num inserito è zero, cambiare num'
  else:
    return 'il num è pos'

# %%
POSNEG(1)

# %%
def POSNEG1(x):
  if x < 0:
    print('il num è neg')
  elif x == 0:
    print('il num inserito è zero, cambiare num')
  else:
    print('il num è pos')

# %%
x = float(input("inserire un numero "))
POSNEG1(x)
# Out:
# inserire un numero 8
# il num è pos

# %%
def PARIDISPARI(x):
  if x % 2 == 0:
    return 'il numero è pari'
  else:
    return 'il numero è dispari'

# %%
x = int(input('inserire numero: '))
print(PARIDISPARI(x))
# Out:
# inserire numero: 8
# il numero è pari

# %%
''' versione prof'''

def PARIDISPARI(x):
  resto = x%2
  if resto == 0:
    return 'il numero è pari'
  else:
    return 'il numero è dispari'

# %%
def AREATRIANGOLO(x,y):
  area = (x * y) / 2
  return area

# %%
print(AREA(5,5))
# Out:
# 12.5

# %%
x = float(input('inserire base '))
y = float(input('inserire altezza '))

print(AREA(x,y))
# Out:
# inserire base 5
# inserire altezza 9
# 22.5

# %%
# %%writefile formulario.py

def AREATRIANGOLO(x,y):
  area = (x * y) / 2
  return area


''' la funzione %%writefile esiste su notebook.'''
# Out:
# Overwriting formulario.py

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Colab Notebooks/esercitazioni
# Out:
# /content/drive/MyDrive/Colab Notebooks/esercitazioni

# %%
ls
# Out:
# 01_intro.ipynb                 Esercitazione03.ipynb  README.md
# alimentazione-gatto-orig.jpeg  formulario.py
# esercitazione01.ipynb          Markdown_Colab.ipynb

# %%
from formulario import AREATRIANGOLO as A
A(4,7)
# Out:
# 14.0

# %%
def AREACERCHIO (x):
  area = (raggio**2) * 3.14
  return area

# %%
def PERIMETROTRIANGOLO(x,y,z):
  per = x + y + z
  return per

# %%
# %%writefile formulario.py

def AREACERCHIO (x):
  area = (raggio**2) * 3.14
  return area

  
def PERIMETROTRIANGOLO(x,y,z):
  per = x + y + z
  return per
# Out:
# Overwriting formulario.py

# %%
from formulario import PERIMETROTRIANGOLO as PT 

PT(5,5,5)
# Out:
# 15

# %%
ls
# Out:
# drive/  sample_data/
