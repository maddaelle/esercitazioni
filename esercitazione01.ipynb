# %% [markdown]
# # Titolo progetto

# %%
print('ciao a tutti')
print('ciao a tutti')
print('ciao a tutti')

# %% [markdown]
# ## Sottotitolo 1

# %%
 print ('sottotitolo')
 print ('sottotitolo')

# %% [markdown]
# ## Capitolo 1.1

# %% [markdown]
# ### Paragrafo 1

# %% [markdown]
# ## Sottotitolo 2

# %% [markdown]
# ## Capitolo 2

# %% [markdown]
# ### Paragrafo 2.1

# %% [markdown]
# # Titolo 2

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/alimentazione-gatto-orig.jpeg
# Out:
# [Errno 20] Not a directory: '/content/drive/MyDrive/Colab Notebooks/alimentazione-gatto-orig.jpeg'
# /content

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !ls
# Out:
#  alimentazione-gatto-orig.jpeg		'ESERCITAZIONI IN AULA'
# 'Copia di Un benvenuto a Colaboratory'

# %%
from IPython.display import Image
Image('alimentazione-gatto-orig.jpeg')

# %%
from IPython.display import Image
Image ('https://www.my-personaltrainer.it/2021/04/13/alimentazione-gatto-orig.jpeg')

# %%
link = 'https://www.focus.it/images/2021/11/16/gatto_1020x680.jpg'
#link = 'https://www.my-personaltrainer.it/2021/04/13/alimentazione-gatto-orig.jpeg'
Image (link)
